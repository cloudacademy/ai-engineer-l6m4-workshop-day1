# %% [markdown]
# ## Selecting a subset of data

# %%
import pandas as pd

# %%
data = pd.read_csv('cdc.csv')

# %%
data.head()
# Out:
#      genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 0       good        0         1         0      70     175       175   77
# 1       good        0         1         1      64     125       115   33
# 2       good        1         1         1      60     105       105   49
# 3       good        1         1         0      66     132       124   42
# 4  very good        0         1         0      61     150       130   55
#
#   gender
# 0      m
# 1      f
# 2      f
# 3      f
# 4      f

# %%
# selecting a specific column - age
age = data['age']
age.head()
# Out:
# 0    77
# 1    33
# 2    49
# 3    42
# 4    55
# Name: age, dtype: int64

# %%
# selecting several columns - genhlth, smoke100, age
GSA = data[['genhlth','smoke100','age']]
GSA.head()
# Out:
#      genhlth  smoke100  age
# 0       good         0   77
# 1       good         1   33
# 2       good         1   49
# 3       good         0   42
# 4  very good         0   55

# %%
# filtering rows based on conditions - age > 80
over_80 = data[data['age'] > 80]
over_80.head()
# Out:
#        genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 104       poor        1         1         0      71     175       175   87
# 210  excellent        1         1         1      62     116       110   84
# 226       good        0         1         0      64     145       145   82
# 286  very good        1         1         0      61     108       108   85
# 287       good        1         1         1      60     107       107   85
#
#     gender
# 104      m
# 210      f
# 226      f
# 286      f
# 287      f

# %%
over_80.shape
# Out:
# (486, 9)

# %%
# filtering rows based on conditions - genhlth is excellent or very good
health_great = data[data['genhlth'].isin(['excellent','very good'])]
health_great.head()
# Out:
#       genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 4   very good        0         1         0      61     150       130   55
# 5   very good        1         1         0      64     114       114   55
# 6   very good        1         1         0      71     194       185   31
# 7   very good        0         1         0      67     170       160   45
# 10  excellent        1         1         1      69     186       175   46
#
#    gender
# 4       f
# 5       f
# 6       m
# 7       m
# 10      m

# %%
health_great.shape
# Out:
# (11629, 9)

# %%
# ... another way
health_great_1 = data[(data['genhlth']=='excellent') | (data['genhlth']=='very good')]
health_great_1.head()
# Out:
#       genhlth  exerany  hlthplan  smoke100  height  weight  wtdesire  age  \
# 4   very good        0         1         0      61     150       130   55
# 5   very good        1         1         0      64     114       114   55
# 6   very good        1         1         0      71     194       185   31
# 7   very good        0         1         0      67     170       160   45
# 10  excellent        1         1         1      69     186       175   46
#
#    gender
# 4       f
# 5       f
# 6       m
# 7       m
# 10      m

# %%
health_great_1.shape
# Out:
# (11629, 9)

# %%
# selecting both rows and columns - select columns genhlth, age and gender where genhlth is excellent
health_exc = data.loc[data['genhlth']=='excellent',['genhlth','age','gender']]
health_exc.head()
# Out:
#       genhlth  age gender
# 10  excellent   46      m
# 12  excellent   21      m
# 13  excellent   69      m
# 26  excellent   44      f
# 27  excellent   42      f

# %%
health_exc.shape
# Out:
# (4657, 3)
